# %%
import pandas as pd

# %%
df = pd.read_csv('pirates.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1000 non-null   int64
#  1   sex              1000 non-null   object
#  2   age              999 non-null    float64
#  3   height           1000 non-null   float64
#  4   weight           1000 non-null   float64
#  5   headband         999 non-null    object
#  6   college          1000 non-null   object
#  7   tattoos          1000 non-null   int64
#  8   tchests          1000 non-null   int64
#  9   parrots          1000 non-null   object
#  10  favorite.pirate  999 non-null    object
#  11  sword.type       1000 non-null   object
#  12  eyepatch         1000 non-null   int64
#  13  sword.time       999 non-null    float64
#  14  beard.length     1000 non-null   int64
#  15  fav.pixar        1000 non-null   object
# ...

# %%
df.dropna(axis=1, inplace=True)
df.reset_index(inplace=True)

# %%
missing_data = df.isna().any()


for col in missing_data.index:
    if missing_data[col]:
        for index, row in df[df[col].isna()].iterrows():
            print(f"Column: {col}, Row Number: {index}")

# %%
first_5_rows = df.head(5)

num_rows = len(first_5_rows)

print("Number of rows in the first 5 rows of the dataset:", num_rows)
# Out:
# Number of rows in the first 5 rows of the dataset: 5

# %%
parrot_values = [0, 1, 2, 0, 4]  
data_type = None

for value in parrot_values:
    if isinstance(value, str):
        data_type = str
    else:
        data_type = object
        break

print("Inferred data type of 'parrot' column:", data_type)
# Out:
# Inferred data type of 'parrot' column: <class 'object'>

# %%
new_row_df = pd.read_csv('PirateNewRow.csv')
combined_df = pd.concat([df, new_row_df], ignore_index=True)
combined_df.drop(["index"], axis=1, inplace=True)

# %%
combined_df.tail()
# Out:
#       index    id     sex  height  weight college  tattoos  tchests parrots  \
# 996   996.0   997  female  157.20   53.60   JSSFP       13       48       2
# 997   997.0   998    male  175.74   72.40   JSSFP        9       95      14
# 998   998.0   999    male  175.24   70.20   JSSFP        9        6       0
# 999   999.0  1000    male  189.45   84.00   JSSFP       10       36       1
# 1000    NaN  1001  female  187.30   97.12    CCCC       17        3       0
#
#      sword.type  eyepatch  beard.length        fav.pixar  grogg   age  \
# 996     cutlass         0             0     Finding Nemo      8   NaN
# 997     cutlass         1            18  The Incredibles     11   NaN
# 998     cutlass         1            24       Inside Out     10   NaN
# 999     cutlass         0            19               Up     14   NaN
# 1000    cutlass         0             0     Finding Nemo      0  43.0
#
#      headband favorite.pirate  sword.time
# 996       NaN             NaN         NaN
# ...

# %%
new_column_df = pd.read_csv('PirateNewColumn.csv')
merged_df = pd.merge(combined_df, new_column_df, on='id', how='inner')
merged_df.head(20)
# Out:
#     id     sex  height  weight college  tattoos  tchests parrots sword.type  \
# 0    1    male  173.11    70.5   JSSFP        9        0       0    cutlass
# 1    2    male  209.25   105.6   JSSFP        9       11       0    cutlass
# 2    3    male  169.95    77.1    CCCC       10       10       1    cutlass
# 3    4  female  144.29    58.5   JSSFP        2        0       2   scimitar
# 4    5  female  157.85    58.4   JSSFP        9        6       4    cutlass
# 5    6    male  190.20    85.4    CCCC        7       19       0    cutlass
# 6    7  female  158.05    59.6   JSSFP        9        1       7    cutlass
# 7    8  female  172.52    74.5   JSSFP        5       13       7    cutlass
# 8    9  female  164.57    68.7   JSSFP       12       37       2    cutlass
# 9   10    male  183.52    84.7   JSSFP       12       69       4    cutlass
# 10  11  female  162.49    63.5    CCCC       10        1       3    cutlass
# ...

# %%
Smokers = 'desired_column_name'

if Smokers in YourDataFrame.columns:
    desired_column = YourDataFrame[Smokers]
    print(desired_column)
else:
    print(f"Column '{Smokers}')
